# %%
# !pip install "transformers<5.0.0"
# Out:
# Requirement already satisfied: transformers<5.0.0 in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (3.29.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0) (1.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5.0.0) (2026.6.17)

# %%
from transformers import pipeline
pipe = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cuda:0

# %%
# !pip install youtube-transcript-api

from urllib.parse import urlparse, parse_qs
from youtube_transcript_api import YouTubeTranscriptApi

def extract_video_id(url: str) -> str:
    """
    Extract the YouTube video ID from a URL.
    Raises ValueError if no 'v' parameter is found.
    """
    parsed = urlparse(url)
    qs = parse_qs(parsed.query)
    video_ids = qs.get('v')

    if not video_ids:
        raise ValueError(f"No video id found in URL: {url}")
    return video_ids[0]

if __name__ == "__main__":
    url = "https://www.youtube.com/watch?v=PZZz790YnzU"

    video_id = extract_video_id(url)

    api = YouTubeTranscriptApi()
    fetched = api.fetch(video_id, languages=['en']) # returns a FetchedTranscript

    text = "\n".join(snippet.text for snippet in fetched)

print(text)
# Out:
# Requirement already satisfied: youtube-transcript-api in /usr/local/lib/python3.12/dist-packages (1.2.4)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from youtube-transcript-api) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->youtube-transcript-api) (2026.6.17)
# Hello guys, welcome to the channel. In
# this video, I will quickly show you how
# to install Linux Min step by step. This
# will be an easy guide for the beginners.
# So stay tuned and let's get started.
# All right, before we jump into the
# install, here's what you're going to
# need to get started. We're going to need
# an empty USB drive with at least 4 GB
# space. You can use any higher capacity
# USB drive, doesn't matter. And second,
# we're going to need a computer with
# internet access. Doesn't matter if it's
# Windows, Mac OS, or Linux. You just need
# it to download Linux Mint ISO and a tool
# to flash it onto the USB drive. And
# third, make sure you have backed up all
# important data, especially if you plan
# to install Linux Mint on your main
# machine. If you're just trying it out, I
# recommend using a spare laptop or create
# a dual boot setup so that you can keep
# Windows 2. Also, make sure in the bias
# settings to disable fast boot because
# bias fast boot startup skips USB
# detection. You can also disable secure
# boot. Even though Linux Min can work
# with it, disable it. A voice driver
# issues. If you have Intel RST rapid
# storage technology, set it to SATA mode
# or AHCI. This one is critical. RSD and
# RAID modes prevents Mint from seeing
# your drive. Optionally, you might want
# to disable TPM or Bit Locker if
# previously used. Also, if your system
# supports full UFI, you need to disable
# CSM and legacy boot and enable USB boot.
# And finally, a bit of patience and
# curiosity. The process is really simple
# and I'll guide you through it step by
# step. Got everything? Cool. Let's move
# on to downloading Linux Mint.
# First, we need to download Linux Mint
# ISO from the official website. Open your
# browser and head over to the official
# website, linuxmint.com.
# Once you're there, click on the download
# button. You'll see three different
# editions: Cinnamon, XFCE, and Mate. If
# you're not sure which one to pick, go
# with Cinnamon. It's the most modern and
# userfriendly version. Next, choose a
# download mirror near your location. The
# file is usually around 3 GB, so it might
# take a few minutes depending on your
# connection. Once that done, you're ready
# to create a bootable USB drive and move
# on with installation.
# So, after you have downloaded the ISO
# file that you need, go to the downloads
# folder. I'm going to be using the 7zip
# program which you can download from this
# website 7-zip.org
# and install it. It works on Windows 64
# and 32bit as well as arm 64 and it works
# with various archive formats. So go
# ahead and click on this download button
# here. Download the software, install it
# and then use it to calculate the SHA 256
# check sum. Just right click on the ISO
# file you have downloaded. Then go to
# sevenzip and choose CRC SHA and then
# choose SHA-26.
# It's going to calculate this SHA 256
# check sum which we need to compare to
# the one that's given on the website.
# Just compare it reference to your
# downloaded ISO. We have cinnamon, so
# we're going to compare it to the
# cinnamon one. Copy the calculated 7zip
# SHA 256 check sum. Then go to the
# website, press Ctrl+ F and paste the
# alpha numeric sequence. If on the
# website it has been highlighted, that
# means that the check sum is the exact
# match and the file has been downloaded
# correctly. So we can proceed to the next
# step. If it doesn't match, that means
# that the file has been corrupted during
# the download or the file that you have
# downloaded is not the same that was
# uploaded at the official website. So,
# you need to redownload it and check it
# again or make sure that you download it
# from the proper source. If you would
# like to know how to verify for
# authenticity, I'm going to attach a link
# for this separate video where I go in
# detail how to verify for the
# authenticity. This process is a bit more
# complicated and suited for more advanced
# users, so I'm not going to show it in
# this video, but if you'd like to do
# that, you can follow through the link in
# the description and check it out.
# We're going to create what's called a
# bootable USB drive. Basically, a USB
# drive that can launch Linux Mint and let
# you install it on the computer. One of
# the best flashing tools to create a
# bootable USB drive on Windows is called
# Rufus. That's the one we're going to be
# using today. But if you're on Linux, you
# can use USB image writer or you can use
# Balena etcher that is also working on
# Windows, Mac OS and Linux. And there is
# also Ventoy and other tools that you can
# use. But if you're on Windows, go with
# Rufus. Open your browser and head over
# to the official Rufus website at
# rufus.ie.
# It's a lightweight and free tool, so you
# don't need to worry about any costs. Get
# the version for your operating system.
# Once the download is complete, simply
# click on the downloaded file. You might
# get a Windows security message pop up.
# Just press yes and the app will start
# right away. Now, grab your USB drive.
# Plug it into your computer. You can use
# any USB drive. Just make sure that there
# is enough storage on the USB drive. For
# the ISO file that you want to flash,
# usually ISO files are like 2 3 GB. So
# the 8 GB USB drive will be sufficient
# for most ISOs. But nowadays it's
# difficult to find such a low capacity
# USB drive. So I'm going to be using a 64
# GB USB drive instead. Make sure the USB
# drive is empty because Rufus will format
# it during the process. So if you have
# any important files on the drive, back
# them up before proceeding. With Rufus
# open and your USB drive connected,
# select the USB drive from the drop- down
# menu. Click select and choose the ISO
# file you want to flash onto the USB
# drive. Usually the rule of thumb if
# you're using it on an older computer,
# just choose MBR because it will work on
# most computers old and new. But if
# you're going to use it on the newer
# computer with UFI system, then you can
# use GPT. But in most cases, MBR works
# great. Once everything is set, double
# check your selections and when you're
# ready, click the start button. If you're
# getting the ISO hybrid image detected
# message, just go with the recommended
# setting such as ISO image mode. But if
# you encounter any issues during boot,
# you can try the DD mode instead. And
# also, if you get other messages, just
# click okay to download extra files. It
# will warn you once again that all data
# on the device will be destroyed. So,
# make sure you have copied all the
# important files before clicking okay.
# Rufus will now format your USB drive and
# copy the ISO file onto it. This might
# take a few minutes depending on the size
# of the ISO and the speed of your USB
# drive. Once it's done, you'll see a
# green bar and a ready message. That's
# it. Your bootable drive is now ready to
# use. If for some reason it doesn't load,
# make sure to disable secure boot on your
# computer. If you don't know how to do
# that, check out my other video that I'm
# going to link in the description.
# Now that we have a bootable USB drive,
# it's time to boot from it and install
# Linux Mint on our computer. Step one,
# first make sure your computer is turned
# off. Plug in the USB stick and then
# power it back on. Step two, as soon as
# the computer starts up, you'll need to
# press a special key to access boot menu.
# This varies by manufacturer. I'll put a
# list of all possible keys for different
# manufacturers so you can pick the one
# that works for your computer. Once
# you're in the boot menu, select your USB
# drive from the list and hit enter. This
# should bring you the Linux Min boot
# menu. Simply select start Linux Mint and
# hit enter. Your computer should now boot
# into Linux Mint live environment which
# is like a demo version of Linux Mint
# that runs directly from the USB without
# installing it yet. Here you can try out
# Linux Mint to make sure it looks good on
# your system and works as expected. If
# everything looks good, click on the
# install Linux Mint icon on the desktop
# to begin the actual installation. The
# installation wizard will pop up. First,
# choose your language.
# Next, select the keyboard layout. I'm
# going to leave English, but if you're in
# a different country, you can choose the
# layout that matches your keyboard. Then,
# you need to connect to the Wi-Fi. It is
# very important because if you don't
# connect to the Wi-Fi, you're not going
# to be able to download any third-p
# partyy drivers. And then, you're going
# to need to do it all afterwards after
# the installation will be completed. So
# choose your network then press connect
# then enter the password for the network
# then press connect. Once it's connected
# as you can see the symbol has changed
# and the connection is established. Then
# press continue. Make sure to select
# install multimedia codex. And finally
# the installer will ask you about the
# installation type. Here where you get a
# few options. First one is erase disk and
# install Linux min. This option will
# erase the entire hard drive and install
# Linux Mint. Use this if you want to
# completely replace Windows with Linux
# Mint. So basically it will remove
# everything from the hard drive. If there
# any information, any documents, make
# sure to copy them before you do that
# because they will be formatted and gone.
# Like you won't be able to recover them.
# Probably never. Make sure to copy
# everything you need before you proceed.
# If you had previously installed Windows
# on this computer, there's going to be an
# option to install Linux Mint alongside
# Windows. This will set up a dual boot,
# allowing you to choose between Windows
# and Linux Mint when you start your
# computer. This is a preferable options
# for beginners. If you want to try out
# Linux, but you still not sure if you're
# going to need Windows, you can use
# Linux, but then you can get back to
# Windows if you need for some programs.
# There is also a more advanced method how
# to install Linux Mint called something
# else. And this method will allow you to
# create partitions manually so that you
# can create your home partition, root
# partition, swap partition manually. You
# can assign different sizes and I have a
# separate video how to do that. I'm also
# going to put a link to that video so you
# can check it out because it is a bit
# more complicated and I don't want to
# make this video too complicated for the
# beginner. So, we're not going to focus
# on it in this video. So, if you're
# interested, please check out that video.
# But we're going to proceed with a clean
# installation. And finally, click install
# now. You will get a confirmation
# message. Press continue. Then choose
# your time zone and press continue. Now,
# you need to set up your user account.
# Enter your name, username, and password.
# This will be your login information for
# Linux Mint. Then press continue. And
# once you confirm, it will start
# installing Linux Mint. This process
# could be around 10 20 minutes depending
# on your system speed. Once the
# installation is complete, it will ask
# you to restart the computer. Make sure
# to remove the USB drive before the
# computer restarts to avoid booting from
# it again.
# Once installation is complete and your
# system restarts, you should see the
# Linux Mint login screen. Then go ahead
# and login with the username and password
# you created during the installation. and
# welcome to Linux Mint. Isn't it looking
# great? The first time you boot into
# Linux Mint, there are a couple of things
# you need to do to make sure your system
# is up to date and ready to go.
# First, update your system. After logging
# in, you'll likely see a notification
# about software updates. You can either
# click on the shield icon and launch
# update manager from there. You can also
# find the update manager through the
# menu. If a new version of the update
# manager is available, apply the update.
# One thing about Linux is that it will
# prompt you to enter your password for
# any important actions that you taken on
# Linux men, such as installing new
# software, removing software, or given
# some permissions. So, get used to enter
# your password quite a lot, but that's a
# trade-off for safety. And you'll see a
# list of updates available for your
# system. Click install updates to
# download and install the latest software
# and security updates. This is important
# to make sure you're running the most
# stable and secure version of Linux Mint.
# What's great about Linux is that it's
# very customizable and it actually gives
# you several methods how to perform the
# same actions. For example, if you need
# to update your system and your software,
# you can use a beginnerfriendly update
# manager, or you can use the terminal
# that will allow you to run a few
# commands, and it will update everything
# for you. But for that, you're going to
# need to learn a few commands, which is
# very simple, and I encourage you to
# learn them. By the way, I have another
# video that will help you learn all these
# commands. I'm going to put a link in the
# description. It is very helpful. It will
# show you the basics command, how to
# update your system, how to maintain your
# system, install software, remove
# software. So, if you want to know how to
# do that using the terminal, you're
# welcome to check it out.
# Anyway, next, you're going to need to
# install additional drivers if needed. To
# do this, open the driver manager by
# searching it in the menu or simply use
# the welcome screen again and click on
# the driver manager. The driver manager
# will automatically detect any hardware
# that needs extra drivers and allow you
# to install them with a few clicks. This
# might include graphics drivers, wireless
# drivers, or printer support. Sometimes
# on some computers, you might run into
# issues where the driver is not supported
# and you might have to look for it
# online. It is not super common anymore,
# but it usually happens with Wi-Fi
# drivers. So, in that case, you're going
# to need to have some internet access.
# For example, you can use like a Ethernet
# cable, find the Wi-Fi drivers, install
# them, and then you can unplug it and
# have internet on your computer. It
# doesn't mean everybody has to do it, but
# sometimes that happens depending on
# different manufacturers of the Wi-Fi
# modules. They might have proprietary
# drivers that are not pre-bundled with
# Linux Vin installation, and you're going
# to have to look them online.
# After updates and drivers are installed,
# feel free to explore. You've got a
# software manager for installing any new
# apps. You can customize your desktop by
# going to the system settings to change
# themes, icons, and other personal
# preferences. It's your system now, so
# make it look how you like it. Linux Mint
# is super customizable. It is way more
# customizable than Windows. So, if you
# want to have your own looking Linux
# Mint, I encourage you to experiment and
# just make it the way you like it. And if
# you need help, the Linux Men community
# is huge and there are plenty of forums,
# guides, and videos out there to help you
# out if you run into any issues. And by
# the way, I want to recommend you my
# playlist that I'm going to put a link in
# the description as well where I have a
# lot of helpful videos about Linux and
# Linux M in particular. So, I welcome you
# to check it out. If you're new to Linux
# and just want to know and get better
# with Linux, it is designed for you. So,
# feel free to check it out. That's it.
# Now you got a fully set up, freshly
# installed Linux bin system. I hope this
# tutorial helped you get comfortable with
# the process. If you find this video
# helpful, please support with your like.
# If you first time to the channel, please
# take a second to click the subscribe
# button and hit the notification bell so
# you don't miss new videos. Also, if you
# still have any comments, questions,
# suggestions, please drop them down in
# the comment section below. I try to read
# every comment and help you if I can. And
# if you like what I'm doing and would
# like to support my channel, you can
# always use Super Thanks or simply buy me
# a coffee. I'm going to put the link in
# description. But this is it for today. I
# hope you have a nice day. I'll see you
# soon. Bye-bye.

# %%
print(len(text))
# Out:
# 15743

# %%
import math
def chunking(Stxt, st , end):
  return Stxt[st : end]

text1 = chunking(text,0,4000)
summerized = pipe(text1)
i=1

for i in range(int(math.ceil(len(text)/4000))):
  text1 = chunking(text,i*4000,(i+1)*4000)
  Nsummerized = pipe(text1)
  summerized[0]['summary_text'] += Nsummerized[0]['summary_text'] + " "

# %%
print(i)
print(text1)
# Out:
# 3
#
# stable and secure version of Linux Mint.
# What's great about Linux is that it's
# very customizable and it actually gives
# you several methods how to perform the
# same actions. For example, if you need
# to update your system and your software,
# you can use a beginnerfriendly update
# manager, or you can use the terminal
# that will allow you to run a few
# commands, and it will update everything
# for you. But for that, you're going to
# need to learn a few commands, which is
# very simple, and I encourage you to
# learn them. By the way, I have another
# video that will help you learn all these
# commands. I'm going to put a link in the
# description. It is very helpful. It will
# show you the basics command, how to
# update your system, how to maintain your
# system, install software, remove
# software. So, if you want to know how to
# do that using the terminal, you're
# welcome to check it out.
# Anyway, next, you're going to need to
# install additional drivers if needed. To
# do this, open the driver manager by
# searching it in the menu or simply use
# the welcome screen again and click on
# the driver manager. The driver manager
# will automatically detect any hardware
# that needs extra drivers and allow you
# to install them with a few clicks. This
# might include graphics drivers, wireless
# drivers, or printer support. Sometimes
# on some computers, you might run into
# issues where the driver is not supported
# and you might have to look for it
# online. It is not super common anymore,
# but it usually happens with Wi-Fi
# drivers. So, in that case, you're going
# to need to have some internet access.
# For example, you can use like a Ethernet
# cable, find the Wi-Fi drivers, install
# them, and then you can unplug it and
# have internet on your computer. It
# doesn't mean everybody has to do it, but
# sometimes that happens depending on
# different manufacturers of the Wi-Fi
# modules. They might have proprietary
# drivers that are not pre-bundled with
# Linux Vin installation, and you're going
# to have to look them online.
# After updates and drivers are installed,
# feel free to explore. You've got a
# software manager for installing any new
# apps. You can customize your desktop by
# going to the system settings to change
# themes, icons, and other personal
# preferences. It's your system now, so
# make it look how you like it. Linux Mint
# is super customizable. It is way more
# customizable than Windows. So, if you
# want to have your own looking Linux
# Mint, I encourage you to experiment and
# just make it the way you like it. And if
# you need help, the Linux Men community
# is huge and there are plenty of forums,
# guides, and videos out there to help you
# out if you run into any issues. And by
# the way, I want to recommend you my
# playlist that I'm going to put a link in
# the description as well where I have a
# lot of helpful videos about Linux and
# Linux M in particular. So, I welcome you
# to check it out. If you're new to Linux
# and just want to know and get better
# with Linux, it is designed for you. So,
# feel free to check it out. That's it.
# Now you got a fully set up, freshly
# installed Linux bin system. I hope this
# tutorial helped you get comfortable with
# the process. If you find this video
# helpful, please support with your like.
# If you first time to the channel, please
# take a second to click the subscribe
# button and hit the notification bell so
# you don't miss new videos. Also, if you
# still have any comments, questions,
# suggestions, please drop them down in
# the comment section below. I try to read
# every comment and help you if I can. And
# if you like what I'm doing and would
# like to support my channel, you can
# always use Super Thanks or simply buy me
# a coffee. I'm going to put the link in
# description. But this is it for today. I
# hope you have a nice day. I'll see you
# soon. Bye-bye.

# %%
print(summerized[0]["summary_text"])
# Out:
# How to install Linux Min step by step. The process is really simple and I'll guide you through it step bystep. We're going to need an empty USB drive with at least 4 GB space and a computer with internet access. You just need to download Linux Mint ISO and a tool to flash it onto the USB drive.How to install Linux Min step by step. The process is really simple and I'll guide you through it step bystep. We're going to need an empty USB drive with at least 4 GB space and a computer with internet access. You just need to download Linux Mint ISO and a tool to flash it onto the USB drive. If you're on Windows, go with the free tool Rufus to create a bootable USB drive. If you're using Linux, you can use USB image writer or Balena etcher. To install Linux Mint on your computer, you'll need a special key to access boot menu. The first time you boot into Linux Mint, there are a couple of things you need to do to make sure your system is up to date and ready to go. Make sure to copy everything you need before you proceed. Then, connect to the Wi-Fi. If you don't, you're not going to be able to download any third-ppartyy drivers. Linux is very customizable and gives you several ways to perform the same actions. To get started with Linux, you're going to need to learn a few commands. The Linux Men community is huge and there are plenty of forums, guides, and videos out there to help you out.

# %%
print(len(summerized[0]['summary_text']))
# Out:
# 1404

# %%
from transformers import pipeline
pipe = pipeline("translation", model="facebook/nllb-200-distilled-600M")
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
translated = pipe(summerized[0]['summary_text'],src_lang="eng_Latn",tgt_lang="arb_Arab")
# Out:
# Your input_length: 342 is bigger than 0.9 * max_length: 200. You might consider increasing your max_length manually, e.g. translator('...', max_length=400)

# %%
print(translated[0]['translation_text'])
# Out:
# كيفية تثبيت Linux Min خطوة بخطوة. العملية بسيطة جداً وسوف نحتاج إلى محرك أقراص USB فارغ مع مساحة 4 غيغابايت على الأقل وسوف نحتاج إلى محرك أقراص USB فارغ مع مساحة 4 غيغابايت على الأقل وكمبيوتر مع إمكانية الوصول إلى الإنترنت. سوف تحتاج فقط إلى تنزيل Linux Mint ISO و أداة لتشغيلها على محرك أقراص USB. كيفية تثبيت Linux Min خطوة بخطوة. العملية بسيطة جداً وسوف أرافقك عليها خطوة بخطوة. سوف نحتاج إلى محرك أقراص USB فارغ مع مساحة 4 غيغابايت على الأقل وكمبيوتر مع إمكانية الوصول إلى الإنترنت. سوف تحتاج فقط إلى تنزيل Linux Mint ISO و محرك أقراص لتشغيلها
